# %% [markdown]
# # EXPLOTARY DATA ANALYSIS ON IRIS DATASET
#
#
# ### Dataset Information
#
#
#
# #### Dataset :- https://gist.github.com/curran/a08a1080b88344b0c8a7
# #### Orignally Published at https://archive.ics.uci.edu/ml/datasets/Iris
#
# This is iris dataset which contains length of varies parameters of three types of flowers namely setosa, versicolor, and virginia. The dataset contains 3 classes of 50 instances each, where each class is a type of flower.
#
#
#
# #### Attributes :-
#
# 1. Sepal length in cm
# 2. Sepal width in cm
# 3. Petal length in cm
# 4. Petal width in cm
# 5. class:
# -- Iris Setosa
# -- Iris Versicolour
# -- Iris Virginica
#
# ##### NOTE - Class contains 3 different types of flowers
#
#
#
# ### OBJECTIVE
#
# #### We have to apply explotary data analysis on this dataset to find out which attribute is useful to classify the diffences in flower, and then we are able to identify the type whenever new data will be encountered

# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
import numpy as np
iris = pd.read_csv('iris.csv') #Loading iris dataset into panda data frame

# %%
iris #viewing the data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 11            4.8          3.4           1.6          0.2     setosa
# 12            4.8          3.0           1.4          0.1     setosa
# ...

# %%
type(iris) #printing the type of iris
# Out:
# pandas.core.frame.DataFrame

# %%
print(iris.shape) #viewing number of columns and rows.(ROW,column)
# Out:
# (150, 5)

# %%
print(iris.columns) #viewing column information
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
type(iris.columns) #printing type of column
# Out:
# pandas.core.indexes.base.Index

# %%
iris["species"].value_counts() #print values present in each class
# Out:
# virginica     50
# setosa        50
# versicolor    50
# Name: species, dtype: int64

# %% [markdown]
# ### Dataset description
# #### Here, all the three classes have equal data points i.e 50 which clearly shows that it is a balanced dataset.

# %%
iris.describe() #describing the whole class
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris_setosa = iris.loc[iris["species"]=="setosa"]
iris_setosa.describe() #describing the setosa class
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count     50.000000    50.000000     50.000000    50.000000
# mean       5.936000     2.770000      4.260000     1.326000
# std        0.516171     0.313798      0.469911     0.197753
# min        4.900000     2.000000      3.000000     1.000000
# 25%        5.600000     2.525000      4.000000     1.200000
# 50%        5.900000     2.800000      4.350000     1.300000
# 75%        6.300000     3.000000      4.600000     1.500000
# max        7.000000     3.400000      5.100000     1.800000

# %%
iris_versicolor = iris.loc[iris["species"]=="versicolor"]
iris_versicolor.describe() #describing the versicolor class
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count     50.000000    50.000000     50.000000    50.000000
# mean       5.936000     2.770000      4.260000     1.326000
# std        0.516171     0.313798      0.469911     0.197753
# min        4.900000     2.000000      3.000000     1.000000
# 25%        5.600000     2.525000      4.000000     1.200000
# 50%        5.900000     2.800000      4.350000     1.300000
# 75%        6.300000     3.000000      4.600000     1.500000
# max        7.000000     3.400000      5.100000     1.800000

# %%
iris_virginica = iris.loc[iris["species"]=="virginica"]
iris_virginica.describe() #describing the virginica class
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count      50.00000    50.000000     50.000000     50.00000
# mean        6.58800     2.974000      5.552000      2.02600
# std         0.63588     0.322497      0.551895      0.27465
# min         4.90000     2.200000      4.500000      1.40000
# 25%         6.22500     2.800000      5.100000      1.80000
# 50%         6.50000     3.000000      5.550000      2.00000
# 75%         6.90000     3.175000      5.875000      2.30000
# max         7.90000     3.800000      6.900000      2.50000

# %% [markdown]
# ## 2-D Scatter Plot
# ##### The main idea is to plot a 2d scatter plot by taking 2 features at a time then after that identifying that if we could be able to diffentiate the three classes of flower in the dataset

# %%
iris.plot(kind='scatter', x='sepal_length', y='sepal_width')
plt.show()

# here the problem is we are not able to visualise ththree classes hence this is not useful
# We have to color the data points by their class

# %%
sns.set_style("whitegrid");
sns.FacetGrid(iris, hue="species", size=4) \
   .map(plt.scatter, "sepal_length", "sepal_width") \
   .add_legend();
plt.show();

# %% [markdown]
# ### Observation
#
# ##### 1) Here we are able to differentiate the data points of three diffentiate classes i.e setosa, versicolor, virginica.
# ##### 2) The problem here is we are not able to seperate the versicolor and virginica but setosa is well sepearated form rest of the two.
# ##### 3) The data point of versicolor and virginica are overlaping so it is not possible here to seperate both the flower.
# ##### 4) while setosa is much more seperable from the other two.
# ##### 5) So, now we have to try all such possible cases with 4 features avalaible by plotting taking 2 at a time.
# ##### 6) 4c2 = 6 such possible combinations.

# %% [markdown]
# # (Pair Plot)
# ### Can be used when number of features are high.
# ### NOTE: the diagnol elements are PDFs for each feature. PDFs are expalined below.

# %%
plt.close();
sns.set_style("whitegrid");
sns.pairplot(iris, hue="species",size=3);
plt.show();

# %%
sns.set_style("whitegrid");
sns.FacetGrid(iris, hue="species", size=4) \
   .map(plt.scatter, "petal_width", "petal_length") \
   .add_legend();
plt.show();

# %% [markdown]
# ## Observation
# Here, as you can see setosa must be clearly seperable and also rest of the two.
# Even if our model is not 100% effective but we are able to seperate three of the classes
#
# Here what we can do is, we can make a simple model by writing a simple if else condition for seperating the three cases
# Case 1:
#     if( (petal_width>=0 && petal_width<0.7 )&&(petal_length>=0 && petal_length<=2 ))
#     print("setosa");
#
# Case 2:
#     if( (petal_width>=1 && petal_width<1.6 )&&(petal_length>=3 && petal_length<=5 ))
#     print("versicolor");
#
# Case 3:
#     if( (petal_width>=1.6 && petal_width<2.5 )&&(petal_length>=5 && petal_length<=7 ))
#     print("virginicar");
#
# Case 4:(Deafult case)
#     printf("No flower);

# %% [markdown]
# # Univaraite Analysis
# #### Performing univariate analysis to understand which features are userful towards classification
# #### 1. Pdf - Probability density function
# #### 2. Cdf - Cumulative Distribution Function
# #### 3. Box plot
# #### 4. Violen plots

# %% [markdown]
# ## 1-D scatter plot
# ##### In this plot we are just plotting point by taking x ccordinate or y ccordinate of a feature and making the other coordinate zero
# ##### 1-D scatter plot of petal length

# %%
import numpy as np
iris_setosa = iris.loc[iris["species"] == "setosa"]
iris_versicolor = iris.loc[iris["species"] == "versicolor"]
iris_virginica = iris.loc[iris["species"] == "virginica"]

plt.plot(iris_setosa["petal_length"], np.zeros_like(iris_setosa['petal_length']), 'o')
plt.plot(iris_versicolor["petal_length"], np.zeros_like(iris_versicolor['petal_length']), 'o')
plt.plot(iris_virginica["petal_length"], np.zeros_like(iris_virginica['petal_length']), 'o')
plt.legend(['Setosa', 'Versicolor', 'Virginica'])
plt.xlabel('Petal_Length')
plt.title('1D plot')

plt.show()

# %% [markdown]
# ## OBSERVATION
# #### After performing 1-D scatter plot, it is clearly visible that the data points are overlapping and it is difficult to seperate the points

# %%
#### Now Performing Histogram plot on the dataset taking a feature at a time
#### And then deciding which plot is more useful to classify it
sns.FacetGrid(iris, hue="species", size=5) \
   .map(sns.distplot, "petal_length") \
   .add_legend();
plt.show();

# %%
sns.FacetGrid(iris, hue="species", size=5) \
   .map(sns.distplot, "petal_width") \
   .add_legend();
plt.title("Histogram")
plt.show();

# %%
sns.FacetGrid(iris, hue="species", size=5) \
   .map(sns.distplot, "sepal_length") \
   .add_legend();
plt.title("Histogram")
plt.show();

# %%
sns.FacetGrid(iris, hue="species", size=5) \
   .map(sns.distplot, "sepal_width") \
   .add_legend();
plt.title("Histogram")
plt.show();

# %% [markdown]
# ## OBSERVATION
# ### 1. By performing histogram plot, it is clear that sepal_length and sepal width feature have many data points overlapping so it is difficult to build a model by taking these two feature.
# ### 2. Petal_length and petal_width is more beneficial while taking a plot
# ### 3. PL>PW>SL>SW this is the order which can be taken into consideration while classifying a dataset

# %%
## Now plotting CDF(cummulative distributive function) and PDF(Probability Density function) to visualize what percentage
## of dataset is under a limit
## Let say we have to know what percentage of datapoints of petal_length is under 1.6 then we have to use CDF

counts, bin_edges = np.histogram(iris_setosa['petal_length'], bins=10, density=True)

pdf = counts/(sum(counts))
print(pdf)
print(bin_edges)

cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)

plt.show()
# Out:
# [0.02 0.02 0.04 0.14 0.24 0.28 0.14 0.08 0.   0.04]
# [1.   1.09 1.18 1.27 1.36 1.45 1.54 1.63 1.72 1.81 1.9 ]

# %%
#### Here as you can

# %%
counts, bin_edges = np.histogram(iris_setosa['petal_length'], bins=10, density=True)

pdf = counts/(sum(counts))
print(pdf)
print(bin_edges)

cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)
##########################################

counts, bin_edges = np.histogram(iris_virginica['petal_length'], bins=10, density=True)

pdf = counts/(sum(counts))
print(pdf)
print(bin_edges)

cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)
##########################################

counts, bin_edges = np.histogram(iris_versicolor['petal_length'], bins=10, density=True)

pdf = counts/(sum(counts))
print(pdf)
print(bin_edges)

cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)

plt.show()
# Out:
# [0.02 0.02 0.04 0.14 0.24 0.28 0.14 0.08 0.   0.04]
# [1.   1.09 1.18 1.27 1.36 1.45 1.54 1.63 1.72 1.81 1.9 ]
# [0.02 0.1  0.24 0.08 0.18 0.16 0.1  0.04 0.02 0.06]
# [4.5  4.74 4.98 5.22 5.46 5.7  5.94 6.18 6.42 6.66 6.9 ]
# [0.02 0.04 0.06 0.04 0.16 0.14 0.12 0.2  0.14 0.08]
# [3.   3.21 3.42 3.63 3.84 4.05 4.26 4.47 4.68 4.89 5.1 ]

# %%
print("Means:")
print(np.mean(iris_setosa["petal_length"]))
#Mean with an outlier.
print(np.mean(np.append(iris_setosa["petal_length"],50)));
print(np.mean(iris_virginica["petal_length"]))
print(np.mean(iris_versicolor["petal_length"]))

print("\nStd-dev:");
print(np.std(iris_setosa["petal_length"]))
print(np.std(iris_virginica["petal_length"]))
print(np.std(iris_versicolor["petal_length"]))
# Out:
# Means:
# 1.464
# 2.4156862745098038
# 5.552
# 4.26
#
# Std-dev:
# 0.17176728442867115
# 0.5463478745268441
# 0.4651881339845204

# %%
#medians
print('\n!!! Medians !!!')
print(np.median(iris_setosa["petal_length"]))
#median with a outlier
print(np.median(np.append(iris_setosa["petal_length"],50)))
print(np.median(iris_virginica["petal_length"]))
print(np.median(iris_versicolor["petal_length"]))

#quantiles
print('\n !!! Quantiles !!!')
print(np.percentile((iris_setosa["petal_length"]),np.arange(0,100,25)))
print(np.percentile((iris_virginica["petal_length"]),np.arange(0,100,25)))      
print(np.percentile((iris_versicolor["petal_length"]),np.arange(0,100,25)))

#90's
print('\n!!! 90 percentile !!!')
print(np.percentile((iris_setosa["petal_length"]),90))
print(np.percentile((iris_virginica["petal_length"]),90))
print(np.percentile((iris_versicolor["petal_length"]),90))

#98's
print("\n!!! 98 percentile !!!")
print(np.percentile((iris_setosa["petal_length"]),98))
print(np.percentile((iris_virginica["petal_length"]),98))
print(np.percentile((iris_versicolor["petal_length"]),98))

#Mean absolute deviation
from statsmodels import robust
print ("\nMedian Absolute Deviation")
print(robust.mad(iris_setosa["petal_length"]))
print(robust.mad(iris_virginica["petal_length"]))
print(robust.mad(iris_versicolor["petal_length"]))
# Out:
# !!! Medians !!!
# 1.5
# 1.5
# 5.55
# 4.35
#
#  !!! Quantiles !!!
# [1.    1.4   1.5   1.575]
# [4.5   5.1   5.55  5.875]
# [3.   4.   4.35 4.6 ]
#
# !!! 90 percentile !!!
# 1.7
# 6.3100000000000005
# 4.8
#
# !!! 98 percentile !!!
# 1.9
# 6.703999999999999
# 5.002
#
# Median Absolute Deviation
# 0.14826022185056031
# 0.6671709983275211
# 0.5189107764769602

# %%
sns.boxplot(x='species',y='petal_length', data=iris)
plt.show()

# %%
sns.violinplot(x="species", y="petal_length", data=iris, size=8)
plt.show()

# %%
#2D Density plot, contors-plot
sns.jointplot(x="petal_length", y="petal_width", data=iris_setosa, kind="kde");
plt.show();
